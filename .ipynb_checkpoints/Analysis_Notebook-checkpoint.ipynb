# %%
### import libraries
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error, r2_score, explained_variance_score, PredictionErrorDisplay
from sklearn.model_selection import KFold, cross_val_score

from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# read the dataset
df = pd.read_csv("data/test.csv")
df.shape
# Out:
# (2191, 4)

# %% [markdown]
# I have utilized some approaches to clean unrelated words within ```df['body']```, such as cleaning blank space, "\n" string,....

# %%
df['body']
# Out:
# 0       EnronOptions Announcement\r\n\r\n\r\nWe have u...
# 1       Marc,\r\n\r\nUnfortunately, today is not going...
# 2       When: Wednesday, June 06, 2001 10:00 AM-11:00 ...
# 3       we were thinking papasitos (we can meet somewh...
# 4       Since you never gave me the $20 for the last t...
#                               ...
# 2186    Thanks for the resume.  She has had some good ...
# 2187    Attached please find the following documents:\...
# 2188    Good to finally hear from.  Judging from your ...
# 2189    It looks like we have our 12 teams.  We will p...
# 2190    We will need this, so I am sending it to you a...
# Name: body, Length: 2191, dtype: object

# %%
## delete '\n' string inside the message
df['body'] = df['body'].str.replace('\n', ' ')
df['body'] = df['body'].str.replace(r'\s+', ' ', regex=True).str.strip()
df['body'] = df['body'].str.replace('=20', ' ', regex=False)
df['body'] = df['body'].str.replace('=01', '', regex=False)

# %%
df['body']
# Out:
# 0       EnronOptions Announcement We have updated the ...
# 1       Marc, Unfortunately, today is not going to wor...
# 2       When: Wednesday, June 06, 2001 10:00 AM-11:00 ...
# 3       we were thinking papasitos (we can meet somewh...
# 4       Since you never gave me the $20 for the last t...
#                               ...
# 2186    Thanks for the resume. She has had some good e...
# 2187    Attached please find the following documents: ...
# 2188    Good to finally hear from. Judging from your e...
# 2189    It looks like we have our 12 teams. We will pr...
# 2190    We will need this, so I am sending it to you a...
# Name: body, Length: 2191, dtype: object

# %% [markdown]
# ### Task 1: Sentiment Labeling

# %%
analyzer = SentimentIntensityAnalyzer()

sentiment_label = []
for sentence in df['body']:
    vs = analyzer.polarity_scores(sentence)
    score = vs['compound']
    if score >= 0.05:
        sentiment_label.append('Positive')
    elif score <= -0.05:
        sentiment_label.append('Negative')
    else:
        sentiment_label.append('Neutral')

# %%
df['Sentiment'] = sentiment_label
df[['body','Sentiment']]
# Out:
#                                                    body Sentiment
# 0     EnronOptions Announcement We have updated the ...  Positive
# 1     Marc, Unfortunately, today is not going to wor...  Positive
# 2     When: Wednesday, June 06, 2001 10:00 AM-11:00 ...   Neutral
# 3     we were thinking papasitos (we can meet somewh...   Neutral
# 4     Since you never gave me the $20 for the last t...  Positive
# ...                                                 ...       ...
# 2186  Thanks for the resume. She has had some good e...  Positive
# 2187  Attached please find the following documents: ...  Positive
# 2188  Good to finally hear from. Judging from your e...  Positive
# 2189  It looks like we have our 12 teams. We will pr...  Positive
# 2190  We will need this, so I am sending it to you a...  Positive
#
# [2191 rows x 2 columns]

# %%
positive_count = (df['Sentiment'] == 'Positive').sum()
neutral_count = (df['Sentiment'] == 'Neutral').sum()
negative_count = (df['Sentiment'] == 'Negative').sum()

# %%
print(f"The number of positive message(s): {positive_count}")
print(f"The number of neutral message(s): {neutral_count}")
print(f"The number of negative message(s): {negative_count}")
# Out:
# The number of positive message(s): 1528
# The number of neutral message(s): 511
# The number of negative message(s): 152

# %% [markdown]
# ### Task 2 : EDA

# %%
print(f"There are {df.shape[0]} emails in this dataset.")
# Out:
# There are 2191 emails in this dataset.

# %%
# Create a variable to represent year only
df['Year'] = pd.to_datetime(df['date']).dt.year
df.head(5)
# Out:
#                                         Subject  \
# 0                          EnronOptions Update!
# 1                                  (No Subject)
# 2  Phone Screen  Interview - Shannon L. Burnham
# 3                         RE: My new work email
# 4                                           Bet
#
#                                                 body       date  \
# 0  EnronOptions Announcement We have updated the ...  5/10/2010
# 1  Marc, Unfortunately, today is not going to wor...  7/29/2010
# 2  When: Wednesday, June 06, 2001 10:00 AM-11:00 ...  7/25/2011
# 3  we were thinking papasitos (we can meet somewh...  3/25/2010
# 4  Since you never gave me the $20 for the last t...  5/21/2011
#
#                       from Sentiment  Year
# 0     sally.beck@enron.com  Positive  2010
# 1      eric.bass@enron.com  Positive  2010
# 2     sally.beck@enron.com   Neutral  2011
# 3  johnny.palmer@enron.com   Neutral  2010
# 4  lydia.delgado@enron.com  Positive  2011

# %%
# Check the numbers of emails each year
df['Year'].value_counts()
# Out:
# Year
# 2011    1097
# 2010    1094
# Name: count, dtype: int64

# %% [markdown]
# ***The difference in number of emails sent between 2010 and 2011 is only 3 emails, so I think it is unnecessary to make a chart to compare because the difference won't be displayed effectively***

# %%
duplication = df.duplicated(subset=['body'])
print(f"There are {len(df[duplication])} duplicates email bodies.")
# Out:
# There are 682 duplicates email bodies.

# %%
# Are the duplicates from the same sender, or different ones?
dupes = df[df.duplicated(subset=['body'], keep=False)]   # keep=False = show ALL copies
# Are they exact duplicate records (same sender AND date)?
print(df.duplicated(subset=['body', 'from', 'date']).sum())
# Out:
# 0

# %% [markdown]
# ***There are 682 duplicates emails with identical messages in the dataset, indicating that I might drop 682 rows (around 30% of dataset). However, I checked if those are exact duplicate emails from same senders and same date. It shows that that is not the case, so despite identical messages, I still keep that for future analysis***

# %%
df['from'].nunique()
## There are only 10 unique senders from 2010 to 2011
# Out:
# 10

# %%
df['Sentiment'].value_counts().plot(kind='bar', rot = 0, color=['#5cb85c', '#adb5bd', '#d9534f'])
plt.ylabel('Number of emails')
plt.xlabel('Sentiment')
plt.show()

# %% [markdown]
# ***The number of positive emails is approximately double of the sum of neutral and negative messages.***

# %%
# Rows = Year, Columns = Sentiment, Values = counts
counts = pd.crosstab(df['Year'], df['Sentiment'])

# Force the column order so the colors always match
counts = counts[['Negative', 'Neutral', 'Positive']]

counts.plot(kind='bar', rot=0, figsize=(8, 5),
            color=['#d9534f', '#adb5bd', '#5cb85c'], edgecolor='black')

plt.title('Sentiment Distribution by Year')
plt.xlabel('Year')
plt.ylabel('Number of emails')
plt.legend(title='Sentiment')
plt.tight_layout()
plt.show()

# %%
pd.crosstab(df['Year'], df['Sentiment'], normalize='index').round(3) * 100
# Out:
# Sentiment  Negative  Neutral  Positive
# Year
# 2010            8.0     25.0      67.1
# 2011            5.9     21.7      72.4

# %% [markdown]
# ***The percentage of positive messages increased from 67.1% to 72.4% while the numbers of neutral and negative messages both decreased from 8% and 25% to 5.9% and 21.7%, respectively.***

# %%
# Email volume month by month across the full 24 months
monthly_volume = df.groupby('Month').size()
monthly_volume.value_counts()
# Out:
# 91    17
# 92     7
# Name: count, dtype: int64

# %% [markdown]
# ***There are 17 months with 91 emails and 7 month with 92 emails, indicating that dates might be assigned evenly (not randomly). It might affect any further analysis, especially task 5 which about 30-day rolling window. Consequently, no meaningful volume trend can be identified over the period***

# %% [markdown]
# ### Task 3: Employee Score Calculation

# %%
"""
24 months 
10 employees
monthly score of 10 employees based on the message (df['body])

Approach: 
Column : Monthly Sentiment Score
Calculate the sentiment score based on df['Sentiment']
        if df['Sentiment'] == 'positive' -> df['Monthly Sentiment Score'] = 1
        else if df['Sentiment'] == 'negative --> df['Monthly Sentiment Score'] = -1
        else: df['Monthly Sentiment Score'] = 0 
Make a "MM-YYYY" column -> there would be 24 unique months
Calculate score of each employee each month = group by month -> then group by employee -> add df["Monthly Sentiment Score']
--> Ensure that the score resets at the beginning of each new month
"""
# Out:
# '\n24 months \n10 employees\nmonthly score of 10 employees based on the message (df[\'body])\n\nApproach: \nColumn : Monthly Sentiment Score\nCalculate the sentiment score based on df[\'Sentiment\']\n        if df[\'Sentiment\'] == \'positive\' -> df[\'Monthly Sentiment Score\'] = 1\n        else if df[\'Sentiment\'] == \'negative --> df[\'Monthly Sentiment Score\'] = -1\n        else: df[\'Monthly Sentiment Score\'] = 0 \nMake a "MM-YYYY" column -> there would be 24 unique months\nCalculate score of each employee each month = group by month -> then group by employee -> add df["Monthly Sentiment Score\']\n--> Ensure that the score resets at the beginning of each new month\n'

# %%
# Set score for each sentiment
score = {'Positive': 1, 'Neutral': 0, 'Negative': -1}

# Assign a score to each message
df['Score'] = df['Sentiment'].map(score)
df.head(10)
# Out:
#                                         Subject  \
# 0                          EnronOptions Update!
# 1                                  (No Subject)
# 2  Phone Screen  Interview - Shannon L. Burnham
# 3                         RE: My new work email
# 4                                           Bet
# 5                                     RE: Favor
# 6                        MG Inventory Summaries
# 7                         Forgot the Attachment
# 8       Garvin Brown - AXIA Sr. Power Scheduler
# 9                   More Dallas ASE Information
#
#                                                 body        date  \
# 0  EnronOptions Announcement We have updated the ...   5/10/2010
# 1  Marc, Unfortunately, today is not going to wor...   7/29/2010
# 2  When: Wednesday, June 06, 2001 10:00 AM-11:00 ...   7/25/2011
# 3  we were thinking papasitos (we can meet somewh...   3/25/2010
# 4  Since you never gave me the $20 for the last t...   5/21/2011
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df['Month'] = df['date'].dt.to_period('M')
df['Month']
# Out:
# 0       2010-05
# 1       2010-07
# 2       2011-07
# 3       2010-03
# 4       2011-05
#          ...
# 2186    2011-06
# 2187    2011-01
# 2188    2011-01
# 2189    2011-03
# 2190    2010-10
# Name: Month, Length: 2191, dtype: period[M]

# %%
monthly_scores = df.groupby(['Month', 'from'])['Score'].sum()
monthly_scores = monthly_scores.reset_index()
monthly_scores = monthly_scores.rename(columns={'from': 'Employee', 'Score': 'Monthly Sentiment Score'})
monthly_scores.head(20)
# Out:
#       Month                     Employee  Monthly Sentiment Score
# 0   2010-01  bobette.riner@ipgdirect.com                        1
# 1   2010-01       don.baughman@enron.com                        5
# 2   2010-01          eric.bass@enron.com                        9
# 3   2010-01        john.arnold@enron.com                        5
# 4   2010-01      johnny.palmer@enron.com                        1
# 5   2010-01      kayne.coulter@enron.com                       13
# 6   2010-01      lydia.delgado@enron.com                        9
# 7   2010-01     patti.thompson@enron.com                        6
# 8   2010-01      rhonda.denton@enron.com                        1
# 9   2010-01         sally.beck@enron.com                        1
# 10  2010-02  bobette.riner@ipgdirect.com                        7
# 11  2010-02       don.baughman@enron.com                        6
# 12  2010-02          eric.bass@enron.com                        2
# ...

# %%
monthly_scores['Month'].unique()
# 2 years = 24 months (2010-2011)
# Out:
# <PeriodArray>
# ['2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06', '2010-07',
#  '2010-08', '2010-09', '2010-10', '2010-11', '2010-12', '2011-01', '2011-02',
#  '2011-03', '2011-04', '2011-05', '2011-06', '2011-07', '2011-08', '2011-09',
#  '2011-10', '2011-11', '2011-12']
# Length: 24, dtype: period[M]

# %%
for employee in monthly_scores['Employee'].unique():
    print(f"{employee}")
    employee_name = monthly_scores[monthly_scores['Employee'] == employee]
    print(employee_name[['Month', 'Monthly Sentiment Score']].head(5))
# Out:
# bobette.riner@ipgdirect.com
#       Month  Monthly Sentiment Score
# 0   2010-01                        1
# 10  2010-02                        7
# 20  2010-03                        6
# 30  2010-04                        3
# 40  2010-05                        2
# don.baughman@enron.com
#       Month  Monthly Sentiment Score
# 1   2010-01                        5
# 11  2010-02                        6
# 21  2010-03                        2
# 31  2010-04                        9
# 41  2010-05                       16
# eric.bass@enron.com
#       Month  Monthly Sentiment Score
# 2   2010-01                        9
# 12  2010-02                        2
# 22  2010-03                        4
# 32  2010-04                        2
# 42  2010-05                        6
# john.arnold@enron.com
#       Month  Monthly Sentiment Score
# 3   2010-01                        5
# 13  2010-02                       11
# 23  2010-03                        7
# 33  2010-04                        8
# ...

# %% [markdown]
# ### Task 4: Employee Ranking

# %%
positive_scores = monthly_scores.sort_values(by=['Month', 'Monthly Sentiment Score', 'Employee'], ascending=[True, False, True])
top_three_positive = positive_scores.groupby('Month').head(3).reset_index(drop=True)
top_three_positive.set_index(['Month', 'Employee', 'Monthly Sentiment Score'])
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
for month in top_three_positive['Month'].unique() :
    print(f'Month: {month}')
    top_positive = top_three_positive[top_three_positive['Month'] == month]
    print(top_positive[['Employee', 'Monthly Sentiment Score']].reset_index(drop=True))
# Out:
# Month: 2010-01
#                   Employee  Monthly Sentiment Score
# 0  kayne.coulter@enron.com                       13
# 1      eric.bass@enron.com                        9
# 2  lydia.delgado@enron.com                        9
# Month: 2010-02
#                       Employee  Monthly Sentiment Score
# 0        john.arnold@enron.com                       11
# 1      johnny.palmer@enron.com                       10
# 2  bobette.riner@ipgdirect.com                        7
# Month: 2010-03
#                       Employee  Monthly Sentiment Score
# 0         sally.beck@enron.com                       11
# 1        john.arnold@enron.com                        7
# 2  bobette.riner@ipgdirect.com                        6
# Month: 2010-04
#                   Employee  Monthly Sentiment Score
# 0   don.baughman@enron.com                        9
# 1  kayne.coulter@enron.com                        9
# 2    john.arnold@enron.com                        8
# Month: 2010-05
# ...

# %%
lowest_scores = monthly_scores.sort_values(by=['Month', 'Monthly Sentiment Score', 'Employee'], ascending=[True, True, True])
top_three_lowest = lowest_scores.groupby('Month').head(3).reset_index(drop=True)
top_three_lowest.set_index(['Month', 'Employee', 'Monthly Sentiment Score'])
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
for month in top_three_lowest['Month'].unique() :
    print(f'Month: {month}')
    top_lowest = top_three_lowest[top_three_lowest['Month'] == month]
    print(top_lowest[['Employee', 'Monthly Sentiment Score']].reset_index(drop=True))
# Out:
# Month: 2010-01
#                       Employee  Monthly Sentiment Score
# 0  bobette.riner@ipgdirect.com                        1
# 1      johnny.palmer@enron.com                        1
# 2      rhonda.denton@enron.com                        1
# Month: 2010-02
#                    Employee  Monthly Sentiment Score
# 0   kayne.coulter@enron.com                        1
# 1   lydia.delgado@enron.com                        1
# 2  patti.thompson@enron.com                        1
# Month: 2010-03
#                   Employee  Monthly Sentiment Score
# 0  rhonda.denton@enron.com                        1
# 1   don.baughman@enron.com                        2
# 2  kayne.coulter@enron.com                        3
# Month: 2010-04
#                       Employee  Monthly Sentiment Score
# 0          eric.bass@enron.com                        2
# 1  bobette.riner@ipgdirect.com                        3
# 2         sally.beck@enron.com                        3
# Month: 2010-05
# ...

# %% [markdown]
# ### Task 5: Flight Risk Identification

# %%
"""
    The task requires us to find who has sent 4 or more negative mails ---> we filtered out the dataframe into only negative mails (df['Sentiment'] == 'Negative')
    We have to sort the dataframe by date and employee so it is easier for us to rolling 30-day period
"""

# Filter negative mails and sort the date
negative_df = df[df['Sentiment'] == 'Negative'].rename(columns={'from': 'Employee', 'date': 'Date'}).copy()
negative_df = negative_df.sort_values(['Employee', 'Date'])

# The 30-day period is rolling count of days, irrespective of months
rolling_30 = negative_df.set_index('Date').groupby('Employee')['Subject'].rolling('30D').count()
rolling_30 = rolling_30.reset_index(name='Neg Count')

# Extract a list of these employees 
flight_risk = rolling_30[rolling_30['Neg Count'] >= 4]['Employee'].unique()
for f in flight_risk :
    print(f"Flight Risk Employees: {f}")
# Out:
# Flight Risk Employees: bobette.riner@ipgdirect.com
# Flight Risk Employees: don.baughman@enron.com
# Flight Risk Employees: johnny.palmer@enron.com
# Flight Risk Employees: sally.beck@enron.com

# %% [markdown]
# ### Task 6: Predictive Modeling

# %%
df['Word Count'] = df['body'].str.split().str.len()

pred_df = df.groupby(['Month', 'from']).agg(Monthly_Score = ('Score', 'sum'),
                                            Message_Count = ('Score', 'size'),
                                            Monthly_Word_Count = ('Word Count', 'sum')).reset_index().rename(columns={'from': 'Employee'})
pred_df
# Out:
#        Month                     Employee  Monthly_Score  Message_Count  \
# 0    2010-01  bobette.riner@ipgdirect.com              1              2
# 1    2010-01       don.baughman@enron.com              5              9
# 2    2010-01          eric.bass@enron.com              9             10
# 3    2010-01        john.arnold@enron.com              5              7
# 4    2010-01      johnny.palmer@enron.com              1              6
# ..       ...                          ...            ...            ...
# 235  2011-12      kayne.coulter@enron.com              6              9
# 236  2011-12      lydia.delgado@enron.com             10             17
# 237  2011-12     patti.thompson@enron.com             12             12
# 238  2011-12      rhonda.denton@enron.com              8             11
# 239  2011-12         sally.beck@enron.com              6              9
#
#      Monthly_Word_Count
# 0                    37
# 1                   282
# 2                   376
# ...

# %%
X = pred_df[['Message_Count', 'Monthly_Word_Count']]
y = pred_df['Monthly_Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

print('Train:', X_train.shape, 'Val:', X_test.shape)
# Out:
# Train: (180, 2) Val: (60, 2)

# %%
model = LinearRegression()
kf_model = KFold(n_splits=5, shuffle=True, random_state=101)

neg_mse     = cross_val_score(model, X_train, y_train, cv=kf_model, scoring='neg_mean_squared_error')
rmse_scores = np.sqrt(-neg_mse)
r2_scores   = cross_val_score(model, X_train, y_train, cv=kf_model, scoring='r2')
mae_scores  = -cross_val_score(model, X_train, y_train, cv=kf_model, scoring='neg_mean_absolute_error')

# %%
cv_table = pd.DataFrame({'Fold': range(1, 6),
                        'RMSE': rmse_scores,
                        'MAE' : mae_scores,
                        'R2'  : r2_scores}).set_index('Fold')
print(cv_table.round(4))
# Out:
#         RMSE     MAE      R2
# Fold
# 1     2.0403  1.5150  0.7400
# 2     1.5332  1.2214  0.7705
# 3     1.3584  1.0387  0.8594
# 4     1.7765  1.2956  0.8273
# 5     1.7360  1.3375  0.7217

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("R2  :", round(r2_score(y_test, y_pred),4))
print("RMSE:", round(np.sqrt(mean_squared_error(y_test, y_pred)),4))
print("MAE :", round(mean_absolute_error(y_test, y_pred),4))
# Out:
# R2  : 0.8006
# RMSE: 2.007
# MAE : 1.4841

# %%
fig, ax = plt.subplots(figsize=(7, 5))
PredictionErrorDisplay.from_estimator(
    model, X_test, y_test, 
    kind="residual_vs_predicted",  # Specifies a Residual vs. Fitted plot
    ax=ax, 
    scatter_kwargs={"alpha": 0.6},
    line_kwargs={'color': 'red'}
)
ax.set_title("Residual vs. Fitted Plot")
plt.ylabel('Residuals')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
PredictionErrorDisplay.from_estimator(
    model, X_test, y_test,
    kind="actual_vs_predicted",   # <- the only change
    ax=ax,
    scatter_kwargs={"alpha": 0.6, "edgecolor": "k", "linewidth": 0.3},
    line_kwargs={'color': 'red', 'linestyle': "-"}
)
ax.set_title("Predicted vs Actual — Test set")
plt.tight_layout()
plt.show()
